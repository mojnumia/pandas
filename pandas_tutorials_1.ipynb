# %%
import pandas as pd

# %% [markdown]
#  # read csv file

# %%
df=pd.read_csv('ufc-master.csv')

# %% [markdown]
# # see first top five data

# %%
df.head()
# Out:
#        R_fighter         B_fighter  R_odds  B_odds        R_ev        B_ev  \
# 0  Anthony Smith  Aleksandar Rakic     225    -278  225.000000   35.971223
# 1  Robbie Lawler        Neil Magny     200    -250  200.000000   40.000000
# 2    Ji Yeon Kim      Alexa Grasso     230    -315  230.000000   31.746032
# 3  Ricardo Lamas        Bill Algeo    -335     240   29.850746  240.000000
# 4    Maki Pitolo   Impa Kasanganay     115    -139  115.000000   71.942446
#
#         date                location country Winner  ...  R_td_attempted_bout  \
# 0  8/29/2020  Las Vegas, Nevada, USA     USA   Blue  ...                  NaN
# 1  8/29/2020  Las Vegas, Nevada, USA     USA   Blue  ...                  NaN
# 2  8/29/2020  Las Vegas, Nevada, USA     USA   Blue  ...                  NaN
# 3  8/29/2020  Las Vegas, Nevada, USA     USA    Red  ...                  NaN
# 4  8/29/2020  Las Vegas, Nevada, USA     USA   Blue  ...                  NaN
#
# ...

# %% [markdown]
# # describe the dataframe

# %%
df.describe()
# Out:
#             R_odds       B_odds         R_ev         B_ev  no_of_rounds  \
# count  4355.000000  4355.000000  4355.000000  4355.000000   4355.000000
# mean   -119.043169    68.561194    95.300310   169.669550      3.179793
# std     271.988147   251.030177    84.381106   139.933966      0.567902
# min   -1700.000000 -1200.000000     5.882353     8.333333      3.000000
# 25%    -255.000000  -145.000000    39.215686    68.965517      3.000000
# 50%    -150.000000   130.000000    66.666667   130.000000      3.000000
# 75%     130.000000   225.000000   130.000000   225.000000      3.000000
# max     775.000000  1300.000000   775.000000  1300.000000      5.000000
#
#        B_current_lose_streak  B_current_win_streak       B_draw  \
# count            4355.000000           4355.000000  4355.000000
# mean                0.467509              0.867049     0.006200
# std                 0.766212              1.306148     0.084151
# ...

# %% [markdown]
# # shape of dataframe

# %%
df.shape
# Out:
# (4355, 137)

# %% [markdown]
# # drop a colums

# %%
df.drop(columns=['R_fighter','B_fighter'],axis=1)
# Out:
#       R_odds  B_odds        R_ev        B_ev       date  \
# 0        225    -278  225.000000   35.971223  8/29/2020
# 1        200    -250  200.000000   40.000000  8/29/2020
# 2        230    -315  230.000000   31.746032  8/29/2020
# 3       -335     240   29.850746  240.000000  8/29/2020
# 4        115    -139  115.000000   71.942446  8/29/2020
# ...      ...     ...         ...         ...        ...
# 4350    -155     135   64.516129  135.000000  3/21/2010
# 4351    -210     175   47.619048  175.000000  3/21/2010
# 4352    -260     220   38.461538  220.000000  3/21/2010
# 4353    -420     335   23.809524  335.000000  3/21/2010
# 4354     140    -160  140.000000   62.500000  3/21/2010
#
#                        location country Winner  title_bout       weight_class  \
# 0        Las Vegas, Nevada, USA     USA   Blue       False  Light Heavyweight
# 1        Las Vegas, Nevada, USA     USA   Blue       False       Welterweight
# ...

# %% [markdown]
# # see your choice columns

# %%
x=df[['R_fighter','B_fighter','B_odds','R_odds']]
x
# Out:
#            R_fighter         B_fighter  B_odds  R_odds
# 0      Anthony Smith  Aleksandar Rakic    -278     225
# 1      Robbie Lawler        Neil Magny    -250     200
# 2        Ji Yeon Kim      Alexa Grasso    -315     230
# 3      Ricardo Lamas        Bill Algeo     240    -335
# 4        Maki Pitolo   Impa Kasanganay    -139     115
# ...              ...               ...     ...     ...
# 4350    Duane Ludwig     Darren Elkins     135    -155
# 4351     John Howard    Daniel Roberts     175    -210
# 4352  Brendan Schaub     Chase Gormley     220    -260
# 4353     Mike Pierce     Julio Paulino     335    -420
# 4354    Eric Schafer       Jason Brilz    -160     140
#
# [4355 rows x 4 columns]

# %% [markdown]
# # read specific location

# %%
x.iloc[2,2]
x.iloc[0,:3]
# Out:
# R_fighter       Anthony Smith
# B_fighter    Aleksandar Rakic
# B_odds                   -278
# Name: 0, dtype: object

# %% [markdown]
# # access row and coloums with iterrows method

# %%
for index,row in x.iterrows():
    print(index,row['R_fighter'])
# Out:
# 0 Anthony Smith
# 1 Robbie Lawler
# 2 Ji Yeon Kim
# 3 Ricardo Lamas
# 4 Maki Pitolo
# 5 Mallory Martin
# 6 Alessio Di Chirico
# 7 Alex Caceres
# 8 Polyana Viana
# 9 Sean Brady
# 10 Pedro Munhoz
# 11 Marcin Prachnio
# 12 Mariya Agapova
# 13 Daniel Rodriguez
# 14 Amanda Lemos
# 15 Austin Hubbard
# 16 Ike Villanueva
# 17 Carlton Minus
# 18 Timur Valiev
# 19 Stipe Miocic
# 20 Sean O'Malley
# 21 Junior Dos Santos
# 22 John Dodson
# 23 Jim Miller
# 24 Ashley Yoder
# 25 Felice Herrig
# 26 Herbert Burns
# 27 TJ Brown
# 28 Chris Daukaus
# 29 Derrick Lewis
# 30 Omari Akhmedov
# 31 Maki Pitolo
# 32 Yana Kunitskaya
# 33 Beneil Dariush
# 34 Tim Means
# 35 Kevin Holland
# 36 Nasrat Haqparast
# 37 Andrew Sanchez
# 38 Gavin Tucker
# 39 Youssef Zalal
# 40 Irwin Rivera
# 41 Derek Brunson
# 42 Joanne Calderwood
# 43 Vicente Luque
# 44 Lando Vannata
# 45 Frankie Saenz
# 46 Johnny Munoz
# 47 Jamall Emmers
# 48 Robert Whittaker
# 49 Mauricio Rua
# 50 Fabricio Werdum
# 51 Carla Esparza
# 52 Paul Craig
# ...

# %% [markdown]
# # loc method to find desire all data

# %%
x.loc[df['R_fighter']=="Amanda Lemos"]
# Out:
#        R_fighter     B_fighter  B_odds  R_odds
# 14  Amanda Lemos  Mizuki Inoue    -137     110
